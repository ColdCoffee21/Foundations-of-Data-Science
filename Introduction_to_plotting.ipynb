# %% [markdown]
# <a href="https://colab.research.google.com/github/ColdCoffee21/Foundations-of-Data-Science/blob/master/Introduction_to_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Class 2

# %% [markdown]
# ###plotting

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %% [markdown]
# ####Line plot

# %%
x = np.array([1,2,3,4,5,6])
y = np.power(x,3)
plt.plot(x,y);
#plt.show()

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
print(plt.rcParams['figure.figsize'])
# Out:
# [6.4, 4.8]

# %%
plt.figure(figsize=(8,3))
x = np.linspace(0,10,40)
y = np.sin(x)
plt.plot(x,y,'y--', linewidth=3) #g-
plt.xlabel("X Axis")
plt.ylabel("Y Axis  ", rotation="horizontal")
plt.show()

# %%
plt.figure(figsize=(10,5))
x = np.array([1,2,3,4,5,6])
y = np.power(x,3)
y2 = np.power(x,2)
plt.plot(x,y,'r-', label="$y=x^3$") #g-
plt.plot(x,y2,'b-', label="$y2=x^2$")
plt.xlabel("X Axis", fontsize=18)
plt.ylabel("Y Axis", fontsize=18)
plt.title("$x^2$ $and$ $x^3$", fontsize=20)
plt.legend(loc="upper right")
plt.show()

# %%
#color, line style, line width, xlabel, y label, legend, fontsize, title, loc for legend
